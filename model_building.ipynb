# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data/dataset.csv')

# %%
data.head()
# Out:
#       Weight    Height        BMI  Body Fat Percentage     BFPcase  Gender  \
# 0  76.811975  1.820521  23.175956            18.281148  Acceptable    Male
# 1  77.721154  1.945498  20.534184            13.731021     Fitness    Male
# 2  87.558726  1.742754  28.828859            42.304631       Obese  Female
# 3  89.473356  1.758318  28.940017            27.958021       Obese    Male
# 4  69.963943  1.722570  23.578732            16.464478     Fitness    Male
#
#    Age      BMIcase  activity_level  Exercise_Schedule
# 0   29       normal               3                  4
# 1   23       normal               1                  6
# 2   57  over weight               2                  5
# 3   41  over weight               2                  5
# 4   19       normal               2                  1

# %% [markdown]
# Data preprocess

# %%
data.shape
# Out:
# (5000, 10)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.isnull().sum()
# Out:
# Weight                 0
# Height                 0
# BMI                    0
# Body Fat Percentage    0
# BFPcase                0
# Gender                 0
# Age                    0
# BMIcase                0
# activity_level         0
# Exercise_Schedule      0
# dtype: int64

# %%
data.head()
# Out:
#       Weight    Height        BMI  Body Fat Percentage     BFPcase  Gender  \
# 0  76.811975  1.820521  23.175956            18.281148  Acceptable    Male
# 1  77.721154  1.945498  20.534184            13.731021     Fitness    Male
# 2  87.558726  1.742754  28.828859            42.304631       Obese  Female
# 3  89.473356  1.758318  28.940017            27.958021       Obese    Male
# 4  69.963943  1.722570  23.578732            16.464478     Fitness    Male
#
#    Age      BMIcase  activity_level  Exercise_Schedule
# 0   29       normal               3                  4
# 1   23       normal               1                  6
# 2   57  over weight               2                  5
# 3   41  over weight               2                  5
# 4   19       normal               2                  1

# %%
data = pd.get_dummies(data)

# %%
x = data.drop('Exercise_Schedule', axis=1)

# %%
y = data['Exercise_Schedule']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
from sklearn .metrics import accuracy_score, f1_score, precision_score, recall_score

def training_scores(y_act, y_pred):
    acc = round(accuracy_score(y_act, y_pred), 3)
    pr = round(precision_score(y_act, y_pred, average='weighted'), 3)
    rec = round(recall_score(y_act, y_pred, average='weighted'), 3)
    f1 = round(f1_score(y_act, y_pred, average='weighted'), 3)
    print(f'Training Scores:\n\tAccuracy = {acc} \n\tPrecission = {pr}\n\tRecall = {rec}\n\tF1score = {f1}')
    
def validation_scores(y_act, y_pred):
    acc = round(accuracy_score(y_act, y_pred), 3)
    pr = round(precision_score(y_act, y_pred, average='weighted'), 3)
    rec = round(recall_score(y_act, y_pred, average='weighted'), 3)
    f1 = round(f1_score(y_act, y_pred, average='weighted'), 3)
    print(f'Testing Scores:\n\tAccuracy = {acc} \n\tPrecission = {pr}\n\tRecall = {rec}\n\tF1score = {f1}')

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)

y_train_pred = lr.predict(x_train)

y_test_pred = lr.predict(x_test)

training_scores(y_train,y_train_pred)
validation_scores(y_test,y_test_pred)
# Out:
# Training Scores:
# 	Accuracy = 0.947
# 	Precission = 0.947
# 	Recall = 0.946
# 	F1score = 0.947
# Testing Scores:
# 	Accuracy = 0.948
# 	Precission = 0.95
# 	Recall = 0.948
# 	F1score = 0.949
# D:\4)Fourth Year\Research\Jupyter_NoteBook\env\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
nb = MultinomialNB()
nb.fit(x_train,y_train)

y_train_pred = nb.predict(x_train)

y_test_pred = nb.predict(x_test)

training_scores(y_train,y_train_pred)
validation_scores(y_test,y_test_pred)
# Out:
# Training Scores:
# 	Accuracy = 0.904
# 	Precission = 0.909
# 	Recall = 0.904
# 	F1score = 0.903
# Testing Scores:
# 	Accuracy = 0.893
# 	Precission = 0.901
# 	Recall = 0.893
# 	F1score = 0.892

# %%
dtc = DecisionTreeClassifier()
dtc.fit(x_train,y_train)

y_train_pred = dtc.predict(x_train)

y_test_pred = dtc.predict(x_test)

training_scores(y_train,y_train_pred)
validation_scores(y_test,y_test_pred)
# Out:
# Training Scores:
# 	Accuracy = 1.0
# 	Precission = 1.0
# 	Recall = 1.0
# 	F1score = 1.0
# Testing Scores:
# 	Accuracy = 1.0
# 	Precission = 1.0
# 	Recall = 1.0
# 	F1score = 1.0

# %%
rfc = RandomForestClassifier()
rfc.fit(x_train,y_train)

y_train_pred = rfc.predict(x_train)

y_test_pred = rfc.predict(x_test)

training_scores(y_train,y_train_pred)
validation_scores(y_test,y_test_pred)
# Out:
# Training Scores:
# 	Accuracy = 1.0
# 	Precission = 1.0
# 	Recall = 1.0
# 	F1score = 1.0
# Testing Scores:
# 	Accuracy = 1.0
# 	Precission = 1.0
# 	Recall = 1.0
# 	F1score = 1.0

# %% [raw]
# Support vector machine

# %%
svc = SVC()
svc.fit(x_train,y_train)

y_train_pred = svc.predict(x_train)

y_test_pred = svc.predict(x_test)

training_scores(y_train,y_train_pred)
validation_scores(y_test,y_test_pred)
# Out:
# Training Scores:
# 	Accuracy = 0.644
# 	Precission = 0.609
# 	Recall = 0.644
# 	F1score = 0.585
# Testing Scores:
# 	Accuracy = 0.633
# 	Precission = 0.582
# 	Recall = 0.633
# 	F1score = 0.573
# D:\4)Fourth Year\Research\Jupyter_NoteBook\env\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\4)Fourth Year\Research\Jupyter_NoteBook\env\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import pickle

with open('model/model.pickle', 'wb') as file:
    pickle.dump(rfc, file)

# %%
data.head()
# Out:
#       Weight    Height        BMI  Body Fat Percentage  Age  activity_level  \
# 0  76.811975  1.820521  23.175956            18.281148   29               3
# 1  77.721154  1.945498  20.534184            13.731021   23               1
# 2  87.558726  1.742754  28.828859            42.304631   57               2
# 3  89.473356  1.758318  28.940017            27.958021   41               2
# 4  69.963943  1.722570  23.578732            16.464478   19               2
#
#    Exercise_Schedule  BFPcase_Acceptable  BFPcase_Athletes  BFPcase_Fitness  \
# 0                  4                True             False            False
# 1                  6               False             False             True
# 2                  5               False             False            False
# 3                  5               False             False            False
# 4                  1               False             False             True
#
#    BFPcase_Obese  Gender_Female  Gender_Male  BMIcase_mild thinness  \
# 0          False          False         True                  False
# 1          False          False         True                  False
# 2           True           True        False                  False
# 3           True          False         True                  False
# 4          False          False         True                  False
#
#    BMIcase_moderate thinness  BMIcase_normal  BMIcase_obese  \
# 0                      False            True          False
# 1                      False            True          False
# 2                      False           False          False
# 3                      False           False          False
# 4                      False            True          False
#
#    BMIcase_over weight  BMIcase_sever thinness  BMIcase_severe obese
# 0                False                   False                 False
# 1                False                   False                 False
# 2                 True                   False                 False
# 3                 True                   False                 False
# 4                False                   False                 False

# %%
x.head()
# Out:
#       Weight    Height        BMI  Body Fat Percentage  Age  activity_level  \
# 0  76.811975  1.820521  23.175956            18.281148   29               3
# 1  77.721154  1.945498  20.534184            13.731021   23               1
# 2  87.558726  1.742754  28.828859            42.304631   57               2
# 3  89.473356  1.758318  28.940017            27.958021   41               2
# 4  69.963943  1.722570  23.578732            16.464478   19               2
#
#    BFPcase_Acceptable  BFPcase_Athletes  BFPcase_Fitness  BFPcase_Obese  \
# 0                True             False            False          False
# 1               False             False             True          False
# 2               False             False            False           True
# 3               False             False            False           True
# 4               False             False             True          False
#
#    Gender_Female  Gender_Male  BMIcase_mild thinness  \
# 0          False         True                  False
# 1          False         True                  False
# 2           True        False                  False
# 3          False         True                  False
# 4          False         True                  False
#
#    BMIcase_moderate thinness  BMIcase_normal  BMIcase_obese  \
# 0                      False            True          False
# 1                      False            True          False
# 2                      False           False          False
# 3                      False           False          False
# 4                      False            True          False
#
#    BMIcase_over weight  BMIcase_sever thinness  BMIcase_severe obese
# 0                False                   False                 False
# 1                False                   False                 False
# 2                 True                   False                 False
# 3                 True                   False                 False
# 4                False                   False                 False
